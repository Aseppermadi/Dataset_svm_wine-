# %% [markdown]
# <a href="https://colab.research.google.com/github/Aseppermadi/Dataset_svm_wine-/blob/main/TUGASKB_asep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
bankdata = pd.read_csv("winequality-red.csv")

# %%
bankdata.shape
# Out:
# (1599, 12)

# %%
bankdata.shape
bankdata.head
# Out:
# <bound method NDFrame.head of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
x = bankdata.drop("quality", axis=1)
y = bankdata["quality"]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20)

# %%
svclassifier = SVC(kernel="linear")
svclassifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svclassifier.predict(x_test)
print(y_pred)
# Out:
# [5 6 6 6 6 5 5 6 5 6 6 6 5 6 5 5 5 6 5 5 6 6 6 5 5 5 6 5 6 6 6 5 6 5 5 5 6
#  5 5 5 5 5 5 6 5 5 5 6 5 5 5 6 6 6 5 5 5 5 6 6 6 5 6 6 6 5 5 6 6 6 5 5 5 5
#  6 6 6 5 5 6 5 6 6 5 5 6 5 5 6 5 6 5 6 6 6 5 5 6 6 5 6 6 6 5 6 5 5 6 6 5 5
#  6 6 5 5 6 6 6 5 6 5 6 6 5 6 6 6 5 6 5 5 5 6 6 5 6 6 5 5 6 6 6 6 6 6 6 5 6
#  6 5 6 5 5 6 6 5 6 5 6 6 6 6 5 5 6 5 5 6 5 6 6 6 6 6 6 5 6 6 5 5 5 6 6 5 6
#  6 6 5 5 5 6 6 6 6 5 5 5 6 5 6 5 5 6 5 6 6 6 6 6 6 6 5 5 5 5 5 5 5 5 6 6 6
#  5 5 6 5 5 5 6 6 6 6 5 5 6 5 5 5 6 6 6 5 6 5 6 6 5 5 5 5 5 6 6 5 6 6 6 5 5
#  5 5 6 5 5 6 5 6 6 6 6 6 5 6 6 5 6 6 5 6 5 6 6 5 6 5 5 5 6 5 6 5 5 5 5 6 6
#  5 6 6 5 6 5 6 5 6 5 5 6 5 6 5 6 5 5 5 6 5 5 6 5]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        10
#            5       0.71      0.74      0.73       149
#            6       0.49      0.69      0.58       117
#            7       0.00      0.00      0.00        37
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.60       320
#    macro avg       0.20      0.24      0.22       320
# weighted avg       0.51      0.60      0.55       320
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(bankdata)
plt.show()

# %%
bankdata.hist()
plt.show()

# %%
dir(bankdata)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
inputs = bankdata

# %%
output = bankdata

# %%
inputs.shape
# Out:
# (1599, 12)

# %% [markdown]
# mohon maaf pak saya tadinya mau membuat matrix seperti yang bapak jelaskan yaitu mengelompokan sebuah data menguynakan garis tengah tapi belum berjalan. dan juga saya tidak memakai modul wine yang ada di dalam python karena saya ingin membuat dataset sendiri secara manual.
